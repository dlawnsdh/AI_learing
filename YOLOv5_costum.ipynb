# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt

# %%
# %cat /content/exex/YOLOv5_ex.v1i.yolov5pytorch/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 3
# names: ['cup', 'hand', 'mouse']

# %%
# %cd /
from glob import glob

train_img_list = glob('/content/exex/YOLOv5_ex.v1i.yolov5pytorch/train/images/*.jpg')
print(len(train_img_list))

val_img_list = glob('/content/exex/YOLOv5_ex.v1i.yolov5pytorch/valid/images/*.jpg')
print(len(val_img_list))

# %%
with open('/content/exex/YOLOv5_ex.v1i.yolov5pytorch/train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')

with open('/content/exex/YOLOv5_ex.v1i.yolov5pytorch/val.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
import yaml

with open('/content/exex/YOLOv5_ex.v1i.yolov5pytorch/data.yaml', 'r') as f:
    data = yaml.safe_load(f)
print(data)

data['train'] = '/content/exex/YOLOv5_ex.v1i.yolov5pytorch/train.txt'
data['val'] = '/content/exex/YOLOv5_ex.v1i.yolov5pytorch/val.txt'

with open('/content/exex/YOLOv5_ex.v1i.yolov5pytorch/data.yaml', 'w') as f:
    yaml.dump(data, f)
print(data)
# Out:
# {'names': ['cup', 'hand', 'mouse'], 'nc': 3, 'train': '/content/datasets/train.txt', 'val': '/content/datasets/val.txt'}
# {'names': ['cup', 'hand', 'mouse'], 'nc': 3, 'train': '/content/exex/YOLOv5_ex.v1i.yolov5pytorch/train.txt', 'val': '/content/exex/YOLOv5_ex.v1i.yolov5pytorch/val.txt'}

# %%
#학습
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 500 --data /content/exex/YOLOv5_ex.v1i.yolov5pytorch/data.yaml --cfg ./models/yolov5m.yaml --weights yolov5m.pt --name custom_yolov5_results
# Out:
# /content/yolov5
# train: weights=yolov5m.pt, cfg=./models/yolov5m.yaml, data=/content/exex/YOLOv5_ex.v1i.yolov5pytorch/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=500, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=custom_yolov5_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-238-gb57abb1 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
from IPython.display import Image
import os

val_img_path = val_img_list[1]

# !python detect.py --weights /content/yolov5/runs/train/custom_yolov5_results2/weights/best.pt --img 416 --conf 0.5 --source "{val_img_path}"

# %%
# !python detect.py --source /content/drive/MyDrive/img/ex2.mp4 --weights /content/yolov5/runs/train/custom_yolov5_results2/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/custom_yolov5_results2/weights/best.pt'], source=/content/drive/MyDrive/img/ex2.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-238-gb57abb1 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20861016 parameters, 0 gradients, 48.0 GFLOPs
# video 1/1 (1/255) /content/drive/MyDrive/img/ex2.mp4: 640x640 1 cup, 1 hand, 1 mouse, Done. (0.083s)
# video 1/1 (2/255) /content/drive/MyDrive/img/ex2.mp4: 640x640 1 cup, 1 hand, 1 mouse, Done. (0.078s)
# video 1/1 (3/255) /content/drive/MyDrive/img/ex2.mp4: 640x640 1 cup, 1 hand, 1 mouse, Done. (0.075s)
# ...
